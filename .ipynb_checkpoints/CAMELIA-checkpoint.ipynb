# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparation" data-toc-modified-id="Preparation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preparation</a></span><ul class="toc-item"><li><span><a href="#Dependencies" data-toc-modified-id="Dependencies-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Dependencies</a></span></li><li><span><a href="#Dataset" data-toc-modified-id="Dataset-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Dataset</a></span><ul class="toc-item"><li><span><a href="#Observations" data-toc-modified-id="Observations-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Observations</a></span></li><li><span><a href="#Traits" data-toc-modified-id="Traits-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Traits</a></span></li><li><span><a href="#SDM-predictions" data-toc-modified-id="SDM-predictions-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>SDM predictions</a></span></li><li><span><a href="#Community-level-indices" data-toc-modified-id="Community-level-indices-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Community-level indices</a></span></li></ul></li><li><span><a href="#Spatial-distribution" data-toc-modified-id="Spatial-distribution-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Spatial distribution</a></span></li></ul></li><li><span><a href="#Initial-evaluation" data-toc-modified-id="Initial-evaluation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Initial evaluation</a></span><ul class="toc-item"><li><span><a href="#PFAL" data-toc-modified-id="PFAL-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>PFAL</a></span></li><li><span><a href="#SDM" data-toc-modified-id="SDM-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>SDM</a></span></li><li><span><a href="#MEM---unscaled" data-toc-modified-id="MEM---unscaled-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>MEM - unscaled</a></span></li><li><span><a href="#MEM---scaled" data-toc-modified-id="MEM---scaled-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>MEM - scaled</a></span></li></ul></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Training" data-toc-modified-id="Training-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Training</a></span></li><li><span><a href="#Synthesis" data-toc-modified-id="Synthesis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Synthesis</a></span></li><li><span><a href="#Sensitivity-analysis" data-toc-modified-id="Sensitivity-analysis-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Sensitivity analysis</a></span></li></ul></li></ul></div>

# %% [markdown]
# # MTNN

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
from scipy.stats import skew, kurtosis

# %%
from utilities.data_utilities import *
from utilities.evaluation import *
from utilities.viz_utilities import *
from utilities.neural_model import *
from utilities.interpretability import *

# %% [markdown]
# ### Dataset

# %% [markdown]
# #### Observations

# %%
metadata = pd.read_csv('data/partition.csv',index_col=0)

# %%
Y = pd.read_csv('data/plant_pa.csv')

# %%
splist = Y.columns.tolist()
sites = Y.index.tolist()
nsite = len(sites)
nspecies = len(splist)

# %%
Y.sum().sort_values(ascending=False).plot.bar(log=True)
# Out:
# <Axes: >

# %%
npos = Y.sum()
nneg = nsite - npos
imb_ratio = nneg / npos

imb_ratio.hist()
plt.title('Imbalance ratios')
# Out:
# Text(0.5, 1.0, 'Imbalance ratios')

# %% [markdown]
# #### Traits

# %%
T_raw = pd.read_csv('data/traits.csv',index_col=0)

# %%
tlist = T_raw.columns.tolist()
ntrait = len(tlist)

# %%
imputer = KNNImputer(n_neighbors=10)
imputer.fit(T_raw)

T = pd.DataFrame(data=imputer.transform(T_raw.loc[splist,tlist]),columns=tlist, index=splist)

# %%
T.hist()
# Out:
# array([[<Axes: title={'center': 'LNC'}>, <Axes: title={'center': 'SLA'}>],
#        [<Axes: title={'center': 'PLH'}>, <Axes: >]], dtype=object)

# %%
trait_scaler = MinMaxScaler()
trait_scaler.fit(T)

T_scaled = pd.DataFrame(data=trait_scaler.transform(T),columns=tlist,index=splist)

# %%
T_scaled.hist()
# Out:
# array([[<Axes: title={'center': 'LNC'}>, <Axes: title={'center': 'SLA'}>],
#        [<Axes: title={'center': 'PLH'}>, <Axes: >]], dtype=object)

# %% [markdown]
# #### SDM predictions

# %%
P_inter = pd.read_csv('data/species_models_pa_inter.csv')
P_extra = pd.read_csv('data/species_models_pa_extra.csv',index_col=0)

# %%
Y.index = P_inter.index = P_extra.index = metadata.index = np.arange(nsite)

# %% [markdown]
# #### Community-level indices

# %%
Y_rich, T_mean, T_std, T_skew, T_kurt = compute_functional_indices(Y,T)

# %%
Y_scaled_rich, T_scaled_mean, T_scaled_std, T_scaled_skew, T_scaled_kurt = compute_functional_indices(Y,T_scaled)

# %%
Y_MEM_rich_inter = pd.read_csv('data/mem/SR_inter.csv',sep=';',decimal=',')
Y_MEM_rich_extra = pd.read_csv('data/mem/SR_extra.csv',sep=';',decimal=',')
Y_MEM_rich_inter['eval_mode']='interpolation'
Y_MEM_rich_extra['eval_mode']='extrapolation'

Y_MEM_rich_inter['fold']=metadata['group_interpolation']
Y_MEM_rich_extra['fold']=metadata['group_extrapolation']

Y_MEM_rich = pd.concat([Y_MEM_rich_inter, Y_MEM_rich_extra],axis=0)

# %% [markdown]
# ### Spatial distribution

# %%
sns.set_style("darkgrid")
sns.scatterplot(data=metadata, x='lon', y='lat', hue='group_extrapolation', palette='viridis',s=5.0)
# Out:
# <Axes: xlabel='lon', ylabel='lat'>

# %%
sns.set_style("darkgrid")
sns.scatterplot(data=metadata, x='lon', y='lat', hue='group_interpolation', palette='viridis',s=5.0)
# Out:
# <Axes: xlabel='lon', ylabel='lat'>

# %% [markdown]
# ## Initial evaluation

# %% [markdown]
# ### PFAL

# %%
comm_perfs = []
jaccard_perfs=[]
eps=1e-6
for eval_mode in ['interpolation','extrapolation']:
    for fold in range(1,5):
        P_train, Y_train, P_test, Y_test = get_species_data(metadata,Y,fold=fold,eval_mode=eval_mode)
        rich_test=Y_MEM_rich[(Y_MEM_rich['eval_mode'] == eval_mode) & (Y_MEM_rich['fold'] == fold)]['SR'].values.reshape(-1, 1)

        ### Raw probability:
        test_comm_perfs, _ = evaluate_pfal(rich_test, P_train, P_test, Y_train, Y_test, splist, tlist, T_scaled, method='raw', do_residual=False, eps=1e-6)
        test_comm_perfs['index'] = test_comm_perfs.index
        test_comm_perfs['fold']=fold
        test_comm_perfs['eval_mode']=eval_mode
        test_comm_perfs['subset']='test'
        test_comm_perfs['jaccard']=["", "", "", "", "", "", "","",""] 
        test_comm_perfs['postprocess']='raw'
        test_comm_perfs['trait']=["", "LNC", "SLA", "PLH", "LNC", "SLA", "PLH","",""]
        test_comm_perfs['indice']=["", "cwm", "cwm", "cwm", "fdis", "fdis", "fdis","",""]
        test_comm_perfs['prr'] = 'False'
        test_comm_perfs['archi']='sdm'
        test_comm_perfs['species_loss'] = 'sdm'
        test_comm_perfs['func_loss']='sdm'  
        test_comm_perfs = test_comm_perfs[['index','r2','mse','pearson','pearson_pv','spearman','spearman_pv','jaccard','postprocess','trait', 'indice', 'fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        comm_perfs.append(test_comm_perfs)
        del test_comm_perfs

        ### With optimized thresholds
        test_comm_perfs, test_jaccard_perfs = evaluate_pfal(rich_test, P_train, P_test, Y_train, Y_test, splist, tlist, T_scaled, method='opth', do_residual=False, eps=1e-6)
        test_comm_perfs['index'] = test_comm_perfs.index
        test_comm_perfs['fold']=fold
        test_comm_perfs['eval_mode']=eval_mode
        test_comm_perfs['subset']='test' 
        test_comm_perfs['postprocess']='opth'
        test_comm_perfs['trait']=["", "LNC", "SLA", "PLH", "LNC", "SLA", "PLH","",""]
        test_comm_perfs['indice']=["", "cwm", "cwm", "cwm", "fdis", "fdis", "fdis","",""]
        test_comm_perfs['fold'] = fold
        test_comm_perfs['eval_mode'] = eval_mode
        test_comm_perfs['prr'] = 'False'
        test_comm_perfs['archi']='sdm'
        test_comm_perfs['species_loss'] = 'sdm'
        test_comm_perfs['func_loss']='sdm'  
        test_comm_perfs = test_comm_perfs[['index','r2','mse','pearson','pearson_pv','spearman','spearman_pv','jaccard','postprocess','trait', 'indice', 'fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        comm_perfs.append(test_comm_perfs)
        del test_comm_perfs
        test_jaccard_perfs = pd.DataFrame({'jaccard': test_jaccard_perfs[0]})
        test_jaccard_perfs['fold']=fold
        test_jaccard_perfs['eval_mode']=eval_mode
        test_jaccard_perfs['subset']='test'
        test_jaccard_perfs['postprocess']='opth'
        test_jaccard_perfs['prr'] = 'False'
        test_jaccard_perfs['archi']='sdm'
        test_jaccard_perfs['species_loss'] = 'sdm'
        test_jaccard_perfs['func_loss']='sdm'  
        test_jaccard_perfs = test_jaccard_perfs[['jaccard','postprocess','fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        jaccard_perfs.append(test_jaccard_perfs)
        del test_jaccard_perfs

        ### With optimized normalized thresholds
        test_comm_perfs, test_jaccard_perfs = evaluate_pfal(rich_test, P_train, P_test, Y_train, Y_test, splist, tlist, T_scaled, method='opth_norm', do_residual=False, eps=1e-6)
        test_comm_perfs['index'] = test_comm_perfs.index
        test_comm_perfs['fold']=fold
        test_comm_perfs['eval_mode']=eval_mode
        test_comm_perfs['subset']='test'
        test_comm_perfs['postprocess']='opth_norm'
        test_comm_perfs['trait']=["", "LNC", "SLA", "PLH", "LNC", "SLA", "PLH","",""]
        test_comm_perfs['indice']=["", "cwm", "cwm", "cwm", "fdis", "fdis", "fdis","",""]
        test_comm_perfs['fold'] = fold
        test_comm_perfs['eval_mode'] = eval_mode
        test_comm_perfs['prr'] = 'False'
        test_comm_perfs['archi']='sdm'
        test_comm_perfs['species_loss'] = 'sdm'
        test_comm_perfs['func_loss']='sdm'  
        test_comm_perfs = test_comm_perfs[['index','r2','mse','pearson','pearson_pv','spearman','spearman_pv','jaccard','postprocess','trait', 'indice', 'fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        comm_perfs.append(test_comm_perfs)
        del test_comm_perfs
        test_jaccard_perfs = pd.DataFrame({'jaccard': test_jaccard_perfs[0]})
        test_jaccard_perfs['fold']=fold
        test_jaccard_perfs['eval_mode']=eval_mode
        test_jaccard_perfs['subset']='test'
        test_jaccard_perfs['postprocess']='opth_norm'
        test_jaccard_perfs['prr'] = 'False'
        test_jaccard_perfs['archi']='sdm'
        test_jaccard_perfs['species_loss'] = 'sdm'
        test_jaccard_perfs['func_loss']='sdm'  
        test_jaccard_perfs = test_jaccard_perfs[['jaccard','postprocess','fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        jaccard_perfs.append(test_jaccard_perfs)
        del test_jaccard_perfs
        
        ### prr
        test_comm_perfs, test_jaccard_perfs = evaluate_pfal(rich_test, P_train, P_test, Y_train, Y_test, splist, tlist, T_scaled, method='prr', do_residual=False, eps=1e-6)
        test_comm_perfs['index'] = test_comm_perfs.index
        test_comm_perfs['fold']=fold
        test_comm_perfs['eval_mode']=eval_mode
        test_comm_perfs['subset']='test'
        test_comm_perfs['postprocess']='prr'
        test_comm_perfs['trait']=["", "LNC", "SLA", "PLH", "LNC", "SLA", "PLH","",""]
        test_comm_perfs['indice']=["", "cwm", "cwm", "cwm", "fdis", "fdis", "fdis","",""]
        test_comm_perfs['fold'] = fold
        test_comm_perfs['eval_mode'] = eval_mode
        test_comm_perfs['prr'] = 'False'
        test_comm_perfs['archi']='sdm'
        test_comm_perfs['species_loss'] = 'sdm'
        test_comm_perfs['func_loss']='sdm'  
        test_comm_perfs = test_comm_perfs[['index','r2','mse','pearson','pearson_pv','spearman','spearman_pv','jaccard','postprocess','trait', 'indice', 'fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        comm_perfs.append(test_comm_perfs)
        del test_comm_perfs
        test_jaccard_perfs = pd.DataFrame({'jaccard': test_jaccard_perfs[0]})
        test_jaccard_perfs['fold']=fold
        test_jaccard_perfs['eval_mode']=eval_mode
        test_jaccard_perfs['subset']='test'
        test_jaccard_perfs['postprocess']='prr'
        test_jaccard_perfs['prr'] = 'False'
        test_jaccard_perfs['archi']='sdm'
        test_jaccard_perfs['species_loss'] = 'sdm'
        test_jaccard_perfs['func_loss']='sdm'  
        test_jaccard_perfs = test_jaccard_perfs[['jaccard','postprocess','fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        jaccard_perfs.append(test_jaccard_perfs)
        del test_jaccard_perfs

        ##### prr norm
        test_comm_perfs, test_jaccard_perfs = evaluate_pfal(rich_test, P_train, P_test, Y_train, Y_test, splist, tlist, T_scaled, method='norm_prr', do_residual=False, eps=1e-6)
        test_comm_perfs['index'] = test_comm_perfs.index
        test_comm_perfs['fold']=fold
        test_comm_perfs['eval_mode']=eval_mode
        test_comm_perfs['subset']='test'
        test_comm_perfs['postprocess']='norm_prr'
        test_comm_perfs['trait']=["", "LNC", "SLA", "PLH", "LNC", "SLA", "PLH","",""]
        test_comm_perfs['indice']=["", "cwm", "cwm", "cwm", "fdis", "fdis", "fdis","",""]
        test_comm_perfs['fold'] = fold
        test_comm_perfs['eval_mode'] = eval_mode
        test_comm_perfs['prr'] = 'False'
        test_comm_perfs['archi']='sdm'
        test_comm_perfs['species_loss'] = 'sdm'
        test_comm_perfs['func_loss']='sdm'  
        test_comm_perfs = test_comm_perfs[['index','r2','mse','pearson','pearson_pv','spearman','spearman_pv','jaccard','postprocess','trait', 'indice', 'fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        comm_perfs.append(test_comm_perfs)
        del test_comm_perfs
        test_jaccard_perfs = pd.DataFrame({'jaccard': test_jaccard_perfs[0]})
        test_jaccard_perfs['fold']=fold
        test_jaccard_perfs['eval_mode']=eval_mode
        test_jaccard_perfs['subset']='test'
        test_jaccard_perfs['postprocess']='norm_prr'
        test_jaccard_perfs['prr'] = 'False'
        test_jaccard_perfs['archi']='sdm'
        test_jaccard_perfs['species_loss'] = 'sdm'
        test_jaccard_perfs['func_loss']='sdm'  
        test_jaccard_perfs = test_jaccard_perfs[['jaccard','postprocess','fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        jaccard_perfs.append(test_jaccard_perfs)
        del test_jaccard_perfs
# Out:
# Using interpolation fold 1
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:375: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1027: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:375: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1027: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# ...

# %%
init_comm_perfs = pd.concat(comm_perfs,axis=0,ignore_index=True)
init_comm_perfs.to_csv('results/sdm_CWM_comm_perfs.csv')

# %%
init_jaccard_perfs = pd.concat(jaccard_perfs,axis=0,ignore_index=True)
init_jaccard_perfs.to_csv('results/sdm_CWM_jaccard_perfs.csv')

# %% [markdown]
# ### SDM

# %%
sdm_inter_opt = []

for eval_mode in ['interpolation', 'extrapolation']:
    for fold in range(1, 5):
        P_train, Y_train, P_test, Y_test = get_species_data(metadata, Y, fold=fold, eval_mode=eval_mode)
        th_list = optimize_thres(Y_train, P_train)
        sdm_inter_opt.append((eval_mode, fold, (P_test > th_list) * 1))
# Out:
# Using interpolation fold 1
# Using interpolation fold 2
# Using interpolation fold 3
# Using interpolation fold 4
# Using extrapolation fold 1
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1180: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1180: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Using extrapolation fold 2
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1180: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# Using extrapolation fold 3
# ...

# %%
sdm_inter_opt[3][2].to_csv("sdm_inter_4.csv", index=False)

# %%
all_perfs = []
eps=1e-6
for eval_mode in ['interpolation','extrapolation']:
    for fold in range(1,5):
        P_train, Y_train, P_test, Y_test = get_species_data(metadata,Y,fold=fold,eval_mode=eval_mode)
        
        ### Raw probability: threshold 0.5
        train_perfs = eval_species_perfs(Ys_hat=P_train,Ys_true=Y_train, th_list=0.5)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='raw'
        all_perfs.append(train_perfs)
        del train_perfs
        
        test_perfs = eval_species_perfs(Ys_hat=P_test,Ys_true=Y_test, th_list=0.5)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='raw'
        all_perfs.append(test_perfs)
        del test_perfs
        
        ### With optimized thresholds
        th_list = optimize_thres(Y_train, P_train)
        train_perfs = eval_species_perfs(Ys_hat=P_train,Ys_true=Y_train, th_list=th_list)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='opth'
        all_perfs.append(train_perfs)
        del train_perfs

        test_perfs = eval_species_perfs(Ys_hat=P_test,Ys_true=Y_test, th_list=th_list)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='opth'
        all_perfs.append(test_perfs) 
        del test_perfs
        
        ### With optimized normalized thresholds
        th_list = optimize_thres(Y_train, P_train)
        hat_P_train = (P_train - np.array(th_list))/(1 - np.array(th_list))
        hat_P_train = hat_P_train.clip(lower=0,upper=1)
        train_perfs = eval_species_perfs(Ys_hat=hat_P_train,Ys_true=Y_train, th_list=th_list)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='opth_norm'
        all_perfs.append(train_perfs)
        del train_perfs
        
        
        hat_P_test = (P_test - np.array(th_list))/(1 - np.array(th_list))
        hat_P_test = hat_P_test.clip(lower=0,upper=1)
        test_perfs = eval_species_perfs(Ys_hat=hat_P_test,Ys_true=Y_test, th_list=th_list)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='opth_norm'
        all_perfs.append(test_perfs) 
        del test_perfs

        
        ### Using PRR rule
        filter_prr = (P_train.rank(axis=1,method='min',ascending=False)<=Y_train.sum(axis=1).values.reshape(-1,1))*1+eps
        Y_hat_prr = P_train*filter_prr   

        ##### MASK
        train_perfs = eval_species_perfs(Ys_hat=filter_prr,Ys_true=Y_train, th_list=eps)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='prr_mask'
        all_perfs.append(train_perfs)
        del train_perfs

        ##### CLIPPED PROBA
        train_perfs = eval_species_perfs(Ys_hat=Y_hat_prr,Ys_true=Y_train, th_list=eps)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='prr'
        all_perfs.append(train_perfs) 
        del train_perfs

        filter_prr = (P_test.rank(axis=1,method='min',ascending=False)<=Y_test.sum(axis=1).values.reshape(-1,1))*1+eps
        Y_hat_prr = P_test*filter_prr   

        ##### MASK
        test_perfs = eval_species_perfs(Ys_hat=filter_prr,Ys_true=Y_test, th_list=eps)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='prr_mask'
        all_perfs.append(test_perfs)
        del test_perfs

        ##### CLIPPED PROBA
        test_perfs = eval_species_perfs(Ys_hat=Y_hat_prr,Ys_true=Y_test, th_list=eps)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='prr'
        all_perfs.append(test_perfs)  
        del test_perfs
        
        
        ### Using PRR rule
        th_list = optimize_thres(Y_train, P_train)
        hat_P_train = (P_train - np.array(th_list))/(1 - np.array(th_list))
        hat_P_train = hat_P_train.clip(lower=0,upper=1)
        
        filter_prr = (hat_P_train.rank(axis=1,method='min',ascending=False)<=Y_train.sum(axis=1).values.reshape(-1,1))*1+eps
        Y_hat_prr = hat_P_train*filter_prr   

        ##### MASK
        train_perfs = eval_species_perfs(Ys_hat=filter_prr,Ys_true=Y_train, th_list=eps)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='prr_mask'
        all_perfs.append(train_perfs)
        del train_perfs

        ##### CLIPPED PROBA
        train_perfs = eval_species_perfs(Ys_hat=Y_hat_prr,Ys_true=Y_train, th_list=eps)
        train_perfs['fold']=fold
        train_perfs['eval_mode']=eval_mode
        train_perfs['subset']='train'
        train_perfs['postprocessing']='norm_prr'
        all_perfs.append(train_perfs) 
        del train_perfs

        th_list = optimize_thres(Y_train, P_train)
        hat_P_test = (P_test - np.array(th_list))/(1 - np.array(th_list))
        hat_P_test = hat_P_test.clip(lower=0,upper=1)
        filter_prr = (hat_P_test.rank(axis=1,method='min',ascending=False)<=Y_test.sum(axis=1).values.reshape(-1,1))*1+eps
        Y_hat_prr = hat_P_test*filter_prr   

        ##### MASK
        test_perfs = eval_species_perfs(Ys_hat=filter_prr,Ys_true=Y_test, th_list=eps)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='norm_prr_mask'
        all_perfs.append(test_perfs)
        del test_perfs

        ##### CLIPPED PROBA
        test_perfs = eval_species_perfs(Ys_hat=Y_hat_prr,Ys_true=Y_test, th_list=eps)
        test_perfs['fold']=fold
        test_perfs['eval_mode']=eval_mode
        test_perfs['subset']='test'
        test_perfs['postprocessing']='norm_prr'
        all_perfs.append(test_perfs)
# Out:
# Using interpolation fold 1
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:375: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1027: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:375: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# C:\Users\saras\anaconda3\envs\ml_env\lib\site-packages\sklearn\metrics\_ranking.py:1027: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# ...

# %%
all_perfs[101]['auc'].mean()

# %%
init_species_perfs = pd.concat(all_perfs,axis=0,ignore_index=True)

# %%
init_species_perfs.to_csv('results/sdm_CWM_species_perfs.csv')

# %%
sns.jointplot(data=init_species_perfs.query('subset=="test" & eval_mode=="interpolation"'),
              x='sensitivity', y='specificity', hue='postprocessing', kind='kde', fill=False)

# %%
for eval_mode in ['interpolation','extrapolation']:
    for fold in range(1,5):
        nsite, nspecies = Y.shape
    
        if eval_mode=="interpolation":
            P = pd.read_csv('data/species_models_pa_inter.csv')
        else:
            P = pd.read_csv('data/species_models_pa_extra.csv',index_col=0)
            P.columns = Y.columns
    
        Y.index = P.index = metadata.index = np.arange(nsite)
        test_idx=metadata.query('group_%s==%d'%(eval_mode,fold)).index
        train_idx=metadata.query('group_%s!=%d'%(eval_mode,fold)).index
    
        ### Species output
        Y_train = Y.loc[train_idx]
        Y_test = Y.loc[test_idx] 
        
        ### Species input
        P_train = P.loc[train_idx]
        P_test = P.loc[test_idx]
        
        th_list = optimize_thres(Y_train,P_train)
        prediction = (P_test>th_list)*1
        prediction_df = pd.DataFrame(prediction)
        prediction_df.to_csv('results/prediction_CWM%s%s.csv' %(eval_mode, fold))
# Out:
# C:\Users\deschamg\AppData\Local\anaconda3\envs\deepl\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\envs\deepl\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\envs\deepl\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\envs\deepl\Lib\site-packages\sklearn\metrics\_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# ...

# %% [markdown]
# ### MEM - unscaled

# %%
(_, mem_pred_train), (_, mem_pred_test), mem_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='mem',out_comm='mem', trait_scaler=None)
(_, obs_pred_train), (_, obs_pred_test), obs_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='obs',out_comm='obs', trait_scaler=None)
# Out:
# Using extrapolation fold 2
# Output: MEM predicted community indices
# Input: MEM predicted community indices
# Using extrapolation fold 2
# Output: observed community indices
# Input: observed community indices

# %%
mem_perfs = []
for eval_mode in ['interpolation','extrapolation']:
    for fold in range(1,5):
        (_, mem_pred_train), (_, mem_pred_test), mem_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='mem',out_comm='mem', trait_scaler=None)
        (_, obs_pred_train), (_, obs_pred_test), obs_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='obs',out_comm='obs', trait_scaler=None)
        
        comm_perfs = plot_community_pred(Y_test=obs_pred_train,pred=mem_pred_train, tlist=tlist)
        comm_perfs['subset']='train'
        comm_perfs['fold']=fold
        comm_perfs['evaluation']=eval_mode        
        
        mem_perfs.append(comm_perfs)
        
        comm_perfs = plot_community_pred(Y_test=obs_pred_test,pred=mem_pred_test, tlist=tlist)
        comm_perfs['subset']='test'
        comm_perfs['fold']=fold
        comm_perfs['evaluation']=eval_mode        
        
        mem_perfs.append(comm_perfs)        
        
mem_comm_perfs = pd.concat(mem_perfs,axis=0).reset_index()

# %%
mem_comm_perfs.reset_index().to_csv('results/mem_CWM_initial_perfs.csv')

# %% [markdown]
# ### MEM - scaled

# %%
mem_perfs = []
for eval_mode in ['interpolation','extrapolation']:
    for fold in range(1,5):
        (_, mem_pred_train), (_, mem_pred_test), mem_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='mem',out_comm='mem', trait_scaler=trait_scaler)
        (_, obs_pred_train), (_, obs_pred_test), obs_scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='obs',out_comm='obs', trait_scaler=trait_scaler)
        
        comm_perfs = plot_community_pred(Y_test=obs_pred_train,pred=mem_pred_train, tlist=tlist)
        comm_perfs['subset']='train'
        comm_perfs['fold']=fold
        comm_perfs['evaluation']=eval_mode        
        
        mem_perfs.append(comm_perfs)
        
        comm_perfs = plot_community_pred(Y_test=obs_pred_test,pred=mem_pred_test, tlist=tlist)
        comm_perfs['subset']='test'
        comm_perfs['fold']=fold
        comm_perfs['evaluation']=eval_mode        
        
        mem_perfs.append(comm_perfs)        
        
mem_comm_perfs2 = pd.concat(mem_perfs,axis=0).reset_index()

# %%
mem_comm_perfs2.reset_index().to_csv('results/mem_CWM_scaled_initial_perfs.csv')

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Training

# %% [markdown]
# <b> Architectures </b>
# - []
# - [512]
# - [512, 256]
# - [512, 256, 128]
#
# <b> Losses </b>
# - Species: binary_crossentropy, focal loss, weighted binary_crossentropy
# - CWM, FDIS: mse, mae, mape, huber

# %%
loss_dict = {
    'bce': lambda: tfk.losses.BinaryCrossentropy(from_logits=False),
    'fl': lambda: tfk.losses.BinaryFocalCrossentropy(gamma=1.0,from_logits=False),
    'wbce': lambda: tfk.losses.BinaryFocalCrossentropy(apply_class_balancing=True,gamma=0.0,from_logits=False),    
    'wfl': lambda: tfk.losses.BinaryFocalCrossentropy(apply_class_balancing=True,gamma=1.0,from_logits=False),
    'mse': lambda: tfk.losses.MeanSquaredError(),
    'mae': lambda: tfk.losses.MeanAbsoluteError(),
    'msle': lambda: tfk.losses.MeanSquaredLogarithmicError(),
    'mape': lambda: tfk.losses.MeanAbsolutePercentageError(),
    'huber': lambda: tfk.losses.Huber(delta=1.0)
}

archi_dict = {
    'glm' : [],
    'mlp1' : [512],
    'mlp2' : [512, 256],
    'mlp3' : [512, 256, 128]
}

# %%
fold=4
eval_mode='interpolation'
_, (in_test, out_test), scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='mem',out_comm='obs', trait_scaler=None)

(in_train, out_train), _, scalers = generate_dataset(metadata, Y, T, fold=fold,eval_mode=eval_mode,in_comm='obs',out_comm='obs', trait_scaler=None)
# Out:
# Using interpolation fold 4
# Output: observed community indices
# Input: MEM predicted community indices
# Using interpolation fold 4
# Output: observed community indices
# Input: observed community indices

# %%
out_train['cwm']=out_train['cwm'].astype(np.float32)
out_train['fdis']=out_train['fdis'].astype(np.float32)
in_train[0][0]=in_train[0][0].astype(np.float32)
in_train[0][1]=in_train[0][1].astype(np.float32)

# %%
species_loss = 'bce'
func_loss = 'msle'
archi_name = 'mlp1'
apply_prr = False
eps = 0.5

# %%
out_dir = 'results/richesse_train_obsunw_test_degrad_obs_wlspecies10_lossweightedmomentsx10/%s_%s_%s/%s_%d'%(archi_name,species_loss,func_loss,eval_mode,fold)
os.makedirs(out_dir,exist_ok=True)

# %%
set_seed(seed=1234)
# Out:
# Random seed set as 1234

# %%
x=np.log(out_train['cwm'])
weigth_cwm = np.float32(10/(np.quantile(x, 0.95)-np.quantile(x,0.05)))
x=np.log(out_train['fdis'])
weigth_fdis = np.float32(10/(np.quantile(x, 0.95)-np.quantile(x,0.05)))
x=np.log(out_train['richness'])
weigth_richness = np.float32(10/(np.quantile(x, 0.95)-np.quantile(x,0.05)))
#x=out_train['species']
#weigth_species = 10/(np.quantile(x, 0.95)-np.quantile(x,0.05))

# %%
print(weigth_cwm)
print(weigth_fdis)
print(weigth_richness)
# Out:
# 8.83256
# 7.024382
# 7.213475

# %%
trait_matrix = T.values

# %%
archi = archi_dict.get(archi_name)
plant_model = MTNN(num_species=nspecies, num_traits=ntrait, trait_matrix = trait_matrix, apply_prr=apply_prr, optim_rich=True, hidden_units=archi, hidden_activation='relu', out_activation='sigmoid',dropout_rate=0.0,l1=0.0,l2=0.0,name='mtnn')
plant_model.compile(optimizer='adam',
              loss={'species':loss_dict.get(species_loss)(), 
                    'cwm': loss_dict.get(func_loss)(), 
                    'fdis': loss_dict.get(func_loss)(),
                    'richness' : loss_dict.get(func_loss)()
                   },
              loss_weights={'species':10,'cwm':8.83256,'fdis':7.024382, 'richness':7.213475},
              
              metrics={'species':[tfk.metrics.AUC(name='auc',multi_label=True,from_logits=False),
                                  tfk.metrics.AUC(name='aupr',curve='PR',multi_label=True,from_logits=False),
                                  tfk.metrics.Recall(thresholds=eps,name='recall'),
                                  tfk.metrics.Precision(thresholds=eps,name='precision')#,
                                  #tfk.metrics.BinaryAccuracy(threshold=eps,name='binary_accuracy')
                                 ],
                       
                       #'cwm':tfk.metrics.R2Score(class_aggregation="variance_weighted_average"),
                       #'fdis':tfk.metrics.R2Score(class_aggregation="variance_weighted_average"),
                       #'richness':tfk.metrics.R2Score()
                      })

# %%
es_cbk= tfk.callbacks.EarlyStopping(monitor='val_loss',mode='min',patience=10,min_delta=0.0001, start_from_epoch=10)
plant_model.fit(x=in_train,y=out_train,batch_size=64,epochs=500,shuffle=True, 
                validation_data=(in_test, out_test), 
                callbacks=[es_cbk])
# Out:
# Epoch 1/500
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - cwm_loss: 0.9026 - fdis_loss: 1.2794 - loss: 36.8121 - richness_loss: 30.8024 - species_auc: 0.4839 - species_aupr: 0.0343 - species_loss: 3.8204 - species_precision: 0.0294 - species_recall: 0.0778 - val_cwm_loss: 0.5169 - val_fdis_loss: 0.3834 - val_loss: 3.7360 - val_richness_loss: 1.4146 - val_species_auc: 0.5556 - val_species_aupr: 0.0493 - val_species_loss: 1.4148 - val_species_precision: 0.1196 - val_species_recall: 0.0013
# Epoch 2/500
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - cwm_loss: 0.4121 - fdis_loss: 0.3336 - loss: 3.0505 - richness_loss: 0.9482 - species_auc: 0.5656 - species_aupr: 0.0570 - species_loss: 1.3564 - species_precision: 0.2714 - species_recall: 0.0383 - val_cwm_loss: 0.1597 - val_fdis_loss: 0.2431 - val_loss: 2.3097 - val_richness_loss: 0.6529 - val_species_auc: 0.6085 - val_species_aupr: 0.0666 - val_species_loss: 1.2597 - val_species_precision: 0.4023 - val_species_recall: 0.1351
# Epoch 3/500
# ...

# %%
#plot_history(plant_model.history.history, use_skew=False, use_kurt=False, use_rich=True)

# %%
### tfk.models.save_model(plant_model,filepath='%s/model'%out_dir) ## ça marche pas

# %%
#pd.DataFrame(plant_model.history.history).to_csv('%s/history.csv'%out_dir)
#fig = plot_history(plant_model.history.history, use_skew=False, use_kurt=False, use_rich=False)
#fig.savefig('%s/learning.png'%out_dir)

# %%
prediction, species_perfs, comm_perfs, jaccard_perfs = evaluate_prediction(plant_model,
                                T_scaled = T,
                                data_train=(in_train, out_train), 
                                data_test=(in_test, out_test), 
                                splist=splist, tlist=tlist, 
                                method='raw', do_residual=False, eps=1e-6)

all_comm_perfs = [comm_perfs]
all_species_perfs = []
all_jaccard_perfs = []

for method in ['th05','opth','opth_norm','prr','norm_prr']:
    print(method)
    prediction_method, species_perfs, comm_perfs, jaccard_perfs = evaluate_prediction(plant_model,
                                    T_scaled = T,
                                    data_train=(in_train, out_train), 
                                    data_test=(in_test, out_test), 
                                    splist=splist, tlist=tlist, 
                                    method=method, do_residual=False, eps=1e-6)
    prediction_df = pd.DataFrame(prediction_method)
    prediction_df.to_csv('%s/prediction_%s.csv' %(out_dir, method))
    if comm_perfs is not None:
        comm_perfs['postprocess']=method
        all_comm_perfs.append(comm_perfs)
        
    if species_perfs is not None:     
        species_perfs['postprocess']=method
        all_species_perfs.append(species_perfs)
    if jaccard_perfs is not None : 
        jaccard_perfs = pd.DataFrame({'jaccard': jaccard_perfs[0]})
        jaccard_perfs['fold']=fold
        jaccard_perfs['eval_mode']=eval_mode
        jaccard_perfs['subset']='train'
        jaccard_perfs['postprocess']=method
        jaccard_perfs['prr'] = 'False'
        jaccard_perfs['archi']=archi_name
        jaccard_perfs['species_loss'] = species_loss
        jaccard_perfs['func_loss']=func_loss 
        jaccard_perfs = jaccard_perfs[['jaccard','postprocess','fold','eval_mode','prr','subset','archi','species_loss','func_loss']]
        all_jaccard_perfs.append(jaccard_perfs)

    
species_perfs_df = pd.concat(all_species_perfs, axis=0)
comm_perfs_df = pd.concat(all_comm_perfs, axis=0)
comm_perfs_df[['trait','indice']]=[c.split('_') if any([tr in c for tr in tlist]) else ['','richness'] if c=='richness' else ['',''] for c in comm_perfs_df.index]
comm_perfs_df = comm_perfs_df.reset_index()


species_perfs_df['fold']=fold
species_perfs_df['eval_mode']=eval_mode
species_perfs_df['prr']=apply_prr
species_perfs_df['archi']=archi_name
species_perfs_df['species_loss']=species_loss
species_perfs_df['func_loss']=func_loss

comm_perfs_df['fold']=fold
comm_perfs_df['eval_mode']=eval_mode
comm_perfs_df['prr']=apply_prr
comm_perfs_df['archi']=archi_name
comm_perfs_df['species_loss']=species_loss
comm_perfs_df['func_loss']=func_loss

jaccard_perfs_df = pd.concat(all_jaccard_perfs, axis=0)
# Out:
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# th05
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# C:\Users\deschamg\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:993: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:993: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:993: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\deschamg\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:993: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# ...

# %%
result_df = pd.DataFrame(prediction['species'])
result_df.to_csv('%s/prediction.csv' % out_dir)
species_perfs_df.to_csv('%s/species_perfs.csv'%out_dir)
comm_perfs_df.to_csv('%s/comm_perfs.csv'%out_dir)
jaccard_perfs_df.to_csv('%s/jaccard_perfs.csv'%out_dir)

# %%
#max_jaccard = all_jaccard_perfs[1][0].index(max(all_jaccard_perfs[1][0]))

# %%
#pred_train_mlp1 = plant_model.predict(in_train)
#Ys_hat_train = pd.DataFrame(data=pred_train_mlp1['species'], columns=splist)

# %%
#obs_train = out_train
#obs_train['richness'] = out_train['species'].sum(axis=1).reshape(-1,1)
#Ys_true_train = pd.DataFrame(data=obs_train['species'], columns=splist)

# %%
#obs_test = out_test
#obs_test['richness'] = out_test['species'].sum(axis=1).reshape(-1,1)
#Ys_true_test = pd.DataFrame(data=obs_test['species'], columns=splist) 

#pred_test_mlp1 = plant_model.predict(in_test)
#Ys_hat_test = pd.DataFrame(data=pred_test_mlp1['species'], columns=splist)

# %%
#th_list = optimize_thres(Ys_true_train,Ys_hat_train)
#pred_test_mlp1_opth =(Ys_hat_test>th_list)*1
#species_perfs = eval_species_perfs(Ys_hat_test, Ys_true_test, th_list=th_list)
#rich, cwm, fdis, _, _ = compute_functional_indices(pred_test_mlp1_opth,T_scaled)
#pred_test = {
#            'species': (Ys_hat_test>th_list)*1,
#            'cwm': cwm,
#            'fdis': fdis,
#            'richness': rich
#        }

# %%
#pred_test_mlp1_opth

# %%
#Ys_hat_train = pd.DataFrame(in_train[0][:,:nspecies],columns=splist)
#Ys_hat_test = pd.DataFrame(in_test[0][:,:nspecies],columns=splist)
#Ys_true_train = pd.DataFrame(out_train['species'],columns=splist)
#Ys_true_test = pd.DataFrame(out_test['species'],columns=splist)

# %%
#species_perfs

# %%
#th_list = optimize_thres(Ys_true_train,Ys_hat_train)
#species_perfs = eval_species_perfs(Ys_hat_test, Ys_true_test, th_list=th_list)
#rich, cwm, fdis, _, _ = compute_functional_indices(Ys_hat_test,T)
#pred_test = {
#    'species': (Ys_hat_test>th_list)*1,
#    'cwm': cwm,
#    'fdis': fdis,
#    'richness': rich
#}

#jaccard_pred = [jaccard_score(Ys_true_test.iloc[i], (Ys_hat_test > th_list).iloc[i].astype(int)) for i in range(len(Ys_true_test))]


#rich2, cwm2, fdis2, _, _ = compute_functional_indices(Ys_true_test,T)
#obs_test = {
#    'species': Ys_true_test,
#    'cwm': cwm2,
#    'fdis': fdis2,
#    'richness': rich2
#}

# %%
#comm_perfs = plot_community_pred(obs_test,pred_test, tlist,algo='sdm_opth',plot_residual=True)

# %%
#comm_perfs

# %%
#comm_perfs_df = pd.concat([comm_perfs_df, comm_perfs], axis=0)

# %%
#species_perfs['postprocess']='opth'
#species_perfs['fold'] = 4
#species_perfs['eval_mode'] = 'extrapolation'
#species_perfs['prr'] = 'False'
#species_perfs['archi']='sdm'
#species_perfs['species_loss'] = 'sdm'
#species_perfs['func_loss']='sdm'

# %%
#species_perfs_df = pd.concat([species_perfs_df, species_perfs], axis=0)

# %%
# Supposons que vous ayez une liste de noms de méthodes
#method_names = ['th05', 'opth', 'opth_norm', 'prr', 'norm_prr']

# Supposons que jaccard_pred soit une liste de valeurs de Jaccard pour chaque méthode
# et all_jaccard_perfs soit une liste de listes contenant les valeurs de Jaccard pour chaque méthode
# (vous devez organiser vos données de cette manière)

# Créez un scatter plot distinct pour chaque méthode
#for i, method_name in enumerate(method_names):
#    plt.figure()  # Crée une nouvelle figure pour chaque méthode
#    plt.scatter(jaccard_pred, all_jaccard_perfs[i][0])
#    plt.axline((0, 0), (1, 1))
#    plt.xlabel('Jaccard_pred')
#    plt.ylabel('Jaccard_perfs')
#    plt.title(f'Scatter Plot pour la méthode {method_name}')

# Affichez les plots
#plt.show()

# %%
#species_perfs_NN_opth = species_perfs_df.loc[species_perfs_df['postprocess'] == 'opth']

# %%
#len(all_jaccard_perfs)

# %%
#prr_perfs = eval_species_perfs(Ys_hat_test, Ys_true_test, th_list=th_list)
#filter_prr = (hat_P_test.rank(axis=1,method='min',ascending=False)<=Y_test.sum(axis=1).values.reshape(-1,1))*1+eps
#Ys_hat_prr = hat_P_test*filter_prr  
#rich3, cwm3, fdis3, _, _ = compute_functional_indices(Ys_hat_prr,T)
#prr_test = {
#    'species': (Ys_hat_test>th_list)*1,
#    'cwm': cwm3,
#    'fdis': fdis3,
#    'richness': rich3
#}

# %%
comm_perfs_df[['archi','func_loss','species_loss','postprocess','jaccard']].groupby(['archi','func_loss','species_loss','postprocess']).mean()
# Out:
#                                            jaccard
# archi func_loss species_loss postprocess
# mlp1  msle      bce          norm_prr     0.170866
#                              opth         0.096236
#                              opth_norm    0.095508
#                              prr          0.197643

# %% [markdown]
# ### Synthesis

# %%
eval_mode="extrapolation"
fold=4

# %%
all_sp = []
all_comm = []
for func_loss in ['msle']:#,'msle','mae','mape','huber']:
    for archi_name in ['mlp1']: #'glm','mlp1','mlp2','mlp3']:
        df = pd.read_csv('results/train_obs_obs_loss1_10/%s_bce_%s/%s_%d/species_perfs.csv'%(archi_name,func_loss,eval_mode,fold),index_col=0)
        df['postprocess'].fillna('raw', inplace=True)
        all_sp.append(df)
        
        df = pd.read_csv('results/train_obs_obs_loss1_10/%s_bce_%s/%s_%d/comm_perfs.csv'%(archi_name,func_loss,eval_mode,fold),index_col=0, sep=',')
        df['postprocess'].fillna('raw', inplace=True)
        all_comm.append(df)
        
df = pd.read_csv('results/sdm_species_perfs.csv',index_col=0)
df = df.loc[(df['eval_mode'] == eval_mode) & (df['subset'] == 'test') & (df['fold'] == fold)]
df['archi']='sdm'
df['func_loss']='sdm'
df['postprocess']=df['postprocessing']
all_sp.append(df)

df = pd.read_csv('results/sdm_comm_perfs.csv',index_col=0, sep=';')
df = df.loc[(df['eval_mode'] == eval_mode) & (df['subset'] == 'test') & (df['fold'] == fold)]
df['archi']='sdm'
df['func_loss']='sdm'
all_comm.append(df)
#df['postprocess'] = df['postprocess'].replace('prr_clip', 'prr')

# %%
species_results = pd.concat(all_sp,axis=0,ignore_index=True)

# %%
for postproc in ['th05','opth','opth_norm','prr','norm_prr']:
    fig, ax = plt.subplots(1,3,figsize=(15,5))
    sns.barplot(data=species_results.query('postprocess==@postproc'), y='archi', x='auc', hue='func_loss',ax=ax[0])
    sns.barplot(data=species_results.query('postprocess==@postproc'), y='archi', x='tss', hue='func_loss',ax=ax[1])
    sns.barplot(data=species_results.query('postprocess==@postproc'), y='archi', x='prauc', hue='func_loss',ax=ax[2])
    ax[0].set_xlim(0,1)
    ax[1].set_xlim(0,1)
    ax[2].set_xlim(0,1)
    fig.suptitle(postproc)

# %%
comm_results = pd.concat(all_comm,axis=0,ignore_index=True)

# %%
sns.barplot(data=comm_results[comm_results['postprocess'] == 'opth'],y='index',x='pearson', hue='archi')
# Out:
# <Axes: xlabel='pearson', ylabel='index'>

# %%
fig, ax = plt.subplots(1,2, figsize=(25,20), sharex=True)
sns.barplot(data=comm_results[(comm_results['archi'] == 'sdm') & (comm_results['func_loss'] == 'sdm')],y='index',x='pearson', hue='postprocess',ax=ax[0])
ax[0].set_title('sdm')
sns.barplot(data=comm_results[(comm_results['archi'] == 'mlp1') & (comm_results['func_loss'] == 'msle')],y='index',x='pearson', hue='postprocess',ax=ax[1])
ax[1].set_title('mlp1') 
fig.suptitle('Community indices')
fig.tight_layout()

# %%
for postproc in ['th05','opth','opth_norm','prr','norm_prr']:
    fig, ax = plt.subplots(1,3,figsize=(15,5))
    sns.barplot(data=comm_results.query('postprocess==@postproc'),y='archi',x='r2', hue='func_loss', ax=ax[0])
    ax[0].set_xlim(-1,1)
    
    sns.barplot(data=comm_results.query('postprocess==@postproc'),y='archi',x='pearson', hue='func_loss', ax=ax[1])
    ax[1].set_xlim(-1,1)
    
    sns.barplot(data=comm_results.query('postprocess==@postproc'),y='archi',x='spearman', hue='func_loss', ax=ax[2])
    ax[2].set_xlim(-1,1)    
    fig.suptitle(postproc)

# %%
fig, ax = plt.subplots(1,2, figsize=(25,20), sharex=True)
sns.barplot(data=comm_results[(comm_results['archi'] == 'sdm') & (comm_results['func_loss'] == 'sdm')],y='index',x='pearson', hue='postprocess',ax=ax[0])
ax[0].set_title('sdm')
sns.barplot(data=comm_results[(comm_results['archi'] == 'mlp1') & (comm_results['func_loss'] == 'msle')],y='index',x='pearson', hue='postprocess',ax=ax[1])
ax[1].set_title('mlp1') 
fig.suptitle('Community indices')
fig.tight_layout()

# %%
species_perfs

# %%
comm_perfs

# %%
# Lire le fichier CSV dans un DataFrame
prevalence = pd.read_csv('data/prevalence.csv', sep=';')
print(prevalence)

# %%
prevalence

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(4,2,figsize=(8,8))
for i, met in enumerate(['auc','prauc','sensitivity','specificity','precision','f1', 'tss']):
    sns.scatterplot(x=species_perfs[met], y=species_perfs_NN_opth[met],  hue=prevalence['Prevalence'], palette='viridis', ax=ax[i//2, i%2])
    
    x_min = min(np.min(species_perfs[met]), np.min(species_perfs_NN_opth[met]))
    x_max = max(np.max(species_perfs[met]), np.max(species_perfs_NN_opth[met]))
    
    # Tracez la droite x=y en utilisant les valeurs minimales et maximales
    ax[i//2, i%2].plot([x_min, x_max], [x_min, x_max], color='red', linestyle='--')
    
    ax[i//2,i%2].set_xlabel('SDM %s'%met)
    ax[i//2,i%2].set_ylabel('NN %s'%met)
    
    #ax[i//2, i%2].plot([min(species_perfs[met]), max(species_perfs[met])],
     #                 [min(species_perfs_NN_opth[met]), max(species_perfs_NN_opth[met])],
      #                color='red', linestyle='--')
fig.suptitle('NN ~ SDM species performances')
fig.tight_layout()

# %%
species_perfs_df

# %%
eval_comm_perfs(Y, P_inter, splist, tlist, T_scaled=T, eval_mode="interpolation", fold=1, method='raw', do_residual=False, eps=1e-6)

# %% [markdown]
# ### Sensitivity analysis

# %%
pimp_df = compute_pimp(nn_model=plant_model,data_in=in_train,data_out=out_train,nrepet=2,log_period=1,splist=splist,tlist=tlist)

# %%
sns.boxplot(data=pimp_df.reset_index().melt(id_vars=['index']),y='variable',x='value')

# %%
import tensorflow as tf

# Spécifiez le chemin du répertoire du modèle
model_path = 'results/trainobs_testmem/mlp1_bce_msle/extrapolation_4/model/'

# Chargez le modèle .pb
loaded_model = tf.saved_model.load(model_path)

# %%
signatures = loaded_model.signatures

# %%
signatures
